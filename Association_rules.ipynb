# %% [markdown]
# <a href="https://colab.research.google.com/github/Techbae22/Association-Rules/blob/main/Association_rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Apriori Situation**

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %% [markdown]
# **Apriori Library**

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %% [markdown]
# **Support Code**

# %%
#apriori() function evaluates support value for each product.
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.6)
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.8      (5)
# 2      0.8      (7)
# 3      0.6      (9)
# 4      0.6   (5, 7)
# 5      0.6   (9, 5)

# %% [markdown]
# **Support with Column Names**

# %%
frequent_itemsets=apriori(df, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)

# %% [markdown]
# Support value gives us these information:
#
#
# * 60 percent of 100 purchases are "Hat"
#
# * 80 percent of 100 purchases are "Pants"
#
# * 80 percent of 100 purchases are "Scarf"
#
# * 60 percent of 100 purchases are "Skirt"
#
# * 60 percent of 100 purchases are "Scarf" and "Pants"
#
# * 60 percent of 100 purchases are "Pants" and "Skirt"

# %% [markdown]
# **Confidence Code**

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate itemsets with confidence over 70%.
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 1     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        0.75  1.2500      0.12         1.6
# 3        1.00  1.2500      0.12         inf

# %% [markdown]
# * Antecedent support variable tells us probability of antecedent products alone.
#
# * Consequents support variable tells us probability of consequents products alone.
#
# * Support quantifies how many times an item or an itemset appear in a set of transactions. For example, 60% of transactions contain "Scarf" and "Pants".
#
# * Confidence: After buying item X what’s the probability of buying item Y. For example, 75% of transactions containing "Scarf" have "Pants".

# %% [markdown]
# **Lift Code**

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0  1.25      0.12         inf

# %% [markdown]
# Lift: What’s the probability of buying items X and Y together rather than just buying item X. For example, it's more likely to buy "Skirt" and "Pants" together rather than "Skirt" alone. So, it's better to put "Pants" next to "Skirts".

# %% [markdown]
# **Load our data file**

# %%
#Setup initial libraries
import pandas as pd

# %%
#Import dataset
df= pd.read_csv("Market_Basket_Optimisation.csv", delimiter= ",", header= None)

# %%
#Show the head of the dataset
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %% [markdown]
# **Data Visualization**

# %%
import numpy as np

# %%
df_res = pd.DataFrame()
for i in range(len(df.columns)):
    df_res = df_res.append(df[i].value_counts()) 
df_res.head(5)
# Out:
#    mineral water  burgers  turkey  chocolate  frozen vegetables  spaghetti  \
# 0          577.0    576.0   458.0      391.0              373.0      354.0
# 1          484.0     78.0    11.0      223.0              234.0      411.0
# 2          375.0      NaN     NaN      174.0               87.0      279.0
# 3          201.0      NaN     NaN      143.0               18.0      167.0
# 4           84.0      NaN     NaN      115.0                2.0       62.0
#
#    shrimp  grated cheese   eggs  cookies  ...  cauliflower  ketchup  cream  \
# 0   325.0          293.0  279.0    270.0  ...          1.0      1.0    1.0
# 1   153.0           78.0  302.0    101.0  ...          1.0      5.0    1.0
# 2    48.0           21.0  225.0     50.0  ...          1.0      2.0    1.0
# 3     9.0            1.0  181.0     55.0  ...          3.0      6.0    1.0
# 4     NaN            NaN  134.0     45.0  ...          4.0      3.0    1.0
#
#    body spray  oatmeal  tea  water spray  zucchini  napkins   asparagus
# 0         1.0      1.0  NaN          NaN       NaN      NaN         NaN
# 1        13.0      4.0  5.0          1.0      10.0      NaN         NaN
# 2        14.0      5.0  4.0          1.0       2.0      NaN         NaN
# 3         9.0      6.0  1.0          1.0       9.0      1.0         NaN
# 4        15.0      2.0  4.0          NaN      17.0      2.0         NaN
#
# [5 rows x 120 columns]

# %% [markdown]
# In the above, I decided to count all unique values through all columns and build some visualizations.

# %%
df_sum = df_res.sum()
df_sum = df_sum.sort_values(ascending=False)
df_sum
# Out:
# mineral water    1788.0
# eggs             1348.0
# spaghetti        1306.0
# french fries     1282.0
# chocolate        1230.0
#                   ...
# bramble            14.0
# cream               7.0
# napkins             5.0
# water spray         3.0
#  asparagus          1.0
# Length: 120, dtype: float64

# %% [markdown]
# After counting all values through all columns, we can build a frequency plot.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,8))
plt.title("FREQUENCY PLOT")
cnt = 45 # plot only first 'cnt' values
color = plt.cm.spring(np.linspace(0, 1, cnt))
df_sum.head(cnt).plot.bar(color = color)
plt.xticks(rotation = 'vertical')
plt.grid(False)
plt.axis('on')
plt.show()

# %% [markdown]
# We can also use a heat map

# %%
# !pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
import squarify

# %%
plt.figure(figsize=(15,15))
cnt = 40 # plot only first 'cnt' values
color = plt.cm.hot(np.linspace(0, 1, cnt))
df_part = df_sum.head(cnt)
squarify.plot(sizes = df_part.values, label = df_part.index, alpha=.8, color = color, text_kwargs={'fontsize':8})
plt.axis('off')
plt.show()

# %% [markdown]
# **Apriori Preparation**
#
# Before we convert the dataset to a transaction view, we should convert pandas-data to list-data and then list-data to numpy-data.

# %% [markdown]
# **Making each customer's transaction an identical list**

# %%
arr = []
for i in range(df.shape[0]):
    arr.append([str(df.values[i,j]) for j in range(df.shape[1])])

arr = np.array(arr)

# %%
#Converting our dataset to transaction view
te = TransactionEncoder()
data = te.fit_transform(arr)
data = pd.DataFrame(data, columns = te.columns_)
data
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
#       bacon  barbecue sauce  black tea  blueberries  ...  turkey  \
# 0     False           False      False        False  ...   False
# 1     False           False      False        False  ...   False
# 2     False           False      False        False  ...   False
# 3     False           False      False        False  ...    True
# 4     False           False      False        False  ...   False
# ...     ...             ...        ...          ...  ...     ...
# 7496  False           False      False        False  ...   False
# 7497  False           False      False        False  ...   False
# 7498  False           False      False        False  ...   False
# 7499  False           False      False        False  ...   False
# 7500  False           False      False        False  ...   False
#
#       vegetables mix  water spray  white wine  whole weat flour  \
# 0               True        False       False              True
# 1              False        False       False             False
# 2              False        False       False             False
# 3              False        False       False             False
# 4              False        False       False             False
# ...              ...          ...         ...               ...
# 7496           False        False       False             False
# 7497           False        False       False             False
# 7498           False        False       False             False
# 7499           False        False       False             False
# 7500           False        False       False             False
#
#       whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0                 False             False   True        False     False
# 1                 False             False  False        False     False
# 2                 False             False  False        False     False
# 3                 False             False  False        False     False
# 4                 False              True  False        False     False
# ...                 ...               ...    ...          ...       ...
# 7496              False             False  False        False     False
# 7497              False             False  False        False     False
# 7498              False             False  False        False     False
# 7499              False             False  False        False     False
# 7500              False             False  False         True     False
#
# [7501 rows x 121 columns]

# %%
#Drop missing values
data = data.drop(columns=['nan'])
data.head(5)
# Out:
#     asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0       False     True               True      False     True        False
# 1       False    False              False      False    False        False
# 2       False    False              False      False    False        False
# 3       False    False              False      False     True        False
# 4       False    False              False      False    False        False
#
#    bacon  barbecue sauce  black tea  blueberries  ...  turkey  vegetables mix  \
# 0  False           False      False        False  ...   False            True
# 1  False           False      False        False  ...   False           False
# 2  False           False      False        False  ...   False           False
# 3  False           False      False        False  ...    True           False
# 4  False           False      False        False  ...   False           False
#
#    water spray  white wine  whole weat flour  whole wheat pasta  \
# 0        False       False              True              False
# 1        False       False             False              False
# 2        False       False             False              False
# 3        False       False             False              False
# 4        False       False             False              False
#
#    whole wheat rice   yams  yogurt cake  zucchini
# 0             False   True        False     False
# 1             False  False        False     False
# 2             False  False        False     False
# 3             False  False        False     False
# 4              True  False        False     False
#
# [5 rows x 120 columns]

# %% [markdown]
# **Support Code**
#
#
# Now we will be using Apriori rule to find some dependencies.

# %%
freq_rules = apriori(data, min_support = 0.01, use_colnames = True)
freq_rules
# Out:
#       support                                 itemsets
# 0    0.020397                                (almonds)
# 1    0.033329                                (avocado)
# 2    0.010799                         (barbecue sauce)
# 3    0.014265                              (black tea)
# 4    0.011465                             (body spray)
# ..        ...                                      ...
# 252  0.011065       (ground beef, mineral water, milk)
# 253  0.017064  (ground beef, spaghetti, mineral water)
# 254  0.015731         (spaghetti, mineral water, milk)
# 255  0.010265    (spaghetti, mineral water, olive oil)
# 256  0.011465     (pancakes, spaghetti, mineral water)
#
# [257 rows x 2 columns]

# %%
#Getting itemsets' lengths
freq_rules['length'] = freq_rules['itemsets'].apply(lambda x: len(x))
freq_rules
# Out:
#       support                                 itemsets  length
# 0    0.020397                                (almonds)       1
# 1    0.033329                                (avocado)       1
# 2    0.010799                         (barbecue sauce)       1
# 3    0.014265                              (black tea)       1
# 4    0.011465                             (body spray)       1
# ..        ...                                      ...     ...
# 252  0.011065       (ground beef, mineral water, milk)       3
# 253  0.017064  (ground beef, spaghetti, mineral water)       3
# 254  0.015731         (spaghetti, mineral water, milk)       3
# 255  0.010265    (spaghetti, mineral water, olive oil)       3
# 256  0.011465     (pancakes, spaghetti, mineral water)       3
#
# [257 rows x 3 columns]

# %%
#Getting itemsets with length= 2 and support more than 5%
freq_rules[ (freq_rules['length'] == 2) &
                   (freq_rules['support'] >= 0.05) ]
# Out:
#       support                    itemsets  length
# 118  0.052660  (chocolate, mineral water)       2
# 144  0.050927       (eggs, mineral water)       2
# 224  0.059725  (spaghetti, mineral water)       2

# %%
#Getting itemsets with length= 1 and support more than 5%
freq_rules[ (freq_rules['length'] == 1) &
                   (freq_rules['support'] >= 0.05) ]
# Out:
#      support             itemsets  length
# 6   0.087188            (burgers)       1
# 8   0.081056               (cake)       1
# 12  0.059992            (chicken)       1
# 13  0.163845          (chocolate)       1
# 15  0.080389            (cookies)       1
# 16  0.051060        (cooking oil)       1
# 19  0.179709               (eggs)       1
# 22  0.079323           (escalope)       1
# 24  0.170911       (french fries)       1
# 29  0.063325    (frozen smoothie)       1
# 30  0.095321  (frozen vegetables)       1
# 31  0.052393      (grated cheese)       1
# 32  0.132116          (green tea)       1
# 33  0.098254        (ground beef)       1
# 41  0.076523     (low fat yogurt)       1
# 45  0.129583               (milk)       1
# 46  0.238368      (mineral water)       1
# 52  0.065858          (olive oil)       1
# 53  0.095054           (pancakes)       1
# 61  0.071457             (shrimp)       1
# 62  0.050527               (soup)       1
# 63  0.174110          (spaghetti)       1
# 67  0.068391           (tomatoes)       1
# 68  0.062525             (turkey)       1
# 72  0.058526   (whole wheat rice)       1

# %% [markdown]
# **Confidence Code**

# %%
rules = association_rules(freq_rules, metric="lift", min_threshold=1.2)
rules["antecedents_length"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_length"] = rules["consequents"].apply(lambda x: len(x))
rules.sort_values("lift",ascending=False)
# Out:
#                     antecedents                 consequents  \
# 158             (herb & pepper)               (ground beef)
# 159               (ground beef)             (herb & pepper)
# 326  (spaghetti, mineral water)               (ground beef)
# 327               (ground beef)  (spaghetti, mineral water)
# 341                 (olive oil)  (spaghetti, mineral water)
# ..                          ...                         ...
# 100                      (eggs)            (low fat yogurt)
# 152                    (shrimp)                 (green tea)
# 153                 (green tea)                    (shrimp)
# 109              (french fries)                  (escalope)
# 108                  (escalope)              (french fries)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 158            0.049460            0.098254  0.015998    0.323450  3.291994
# 159            0.098254            0.049460  0.015998    0.162822  3.291994
# 326            0.059725            0.098254  0.017064    0.285714  2.907928
# 327            0.098254            0.059725  0.017064    0.173677  2.907928
# 341            0.065858            0.059725  0.010265    0.155870  2.609786
# ..                  ...                 ...       ...         ...       ...
# 100            0.179709            0.076523  0.016798    0.093472  1.221484
# 152            0.071457            0.132116  0.011465    0.160448  1.214449
# 153            0.132116            0.071457  0.011465    0.086781  1.214449
# 109            0.170911            0.079323  0.016398    0.095944  1.209537
# 108            0.079323            0.170911  0.016398    0.206723  1.209537
#
#      leverage  conviction  antecedents_length  consequents_length
# 158  0.011138    1.332860                   1                   1
# 159  0.011138    1.135410                   1                   1
# 326  0.011196    1.262445                   2                   1
# 327  0.011196    1.137902                   1                   2
# 341  0.006332    1.113898                   1                   2
# ..        ...         ...                 ...                 ...
# 100  0.003046    1.018696                   1                   1
# 152  0.002025    1.033747                   1                   1
# 153  0.002025    1.016780                   1                   1
# 109  0.002841    1.018385                   1                   1
# 108  0.002841    1.045145                   1                   1
#
# [348 rows x 11 columns]

# %% [markdown]
# From the above table, we can easily say that the dependency between (herb & pepper) and (ground beef) is high since lift score is approximately 2.5x of threshold and the confidence score is promising (32%).

# %%
#Sort values based on confidence
rules.sort_values("confidence",ascending=False)
# Out:
#                    antecedents                consequents  antecedent support  \
# 284        (eggs, ground beef)            (mineral water)            0.019997
# 319        (ground beef, milk)            (mineral water)            0.021997
# 260   (ground beef, chocolate)            (mineral water)            0.023064
# 307  (frozen vegetables, milk)            (mineral water)            0.023597
# 214                     (soup)            (mineral water)            0.050527
# ..                         ...                        ...                 ...
# 209            (mineral water)                 (red wine)            0.238368
# 340            (mineral water)     (spaghetti, olive oil)            0.238368
# 38             (mineral water)                  (cereals)            0.238368
# 305            (mineral water)  (french fries, spaghetti)            0.238368
# 289            (mineral water)        (eggs, ground beef)            0.238368
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 284            0.238368  0.010132    0.506667  2.125563  0.005365    1.543848
# 319            0.238368  0.011065    0.503030  2.110308  0.005822    1.532552
# 260            0.238368  0.010932    0.473988  1.988472  0.005434    1.447937
# 307            0.238368  0.011065    0.468927  1.967236  0.005440    1.434136
# 214            0.238368  0.023064    0.456464  1.914955  0.011020    1.401255
# ..                  ...       ...         ...       ...       ...         ...
# 209            0.028130  0.010932    0.045861  1.630358  0.004227    1.018584
# 340            0.022930  0.010265    0.043065  1.878079  0.004799    1.021041
# 38             0.025730  0.010265    0.043065  1.673729  0.004132    1.018115
# 305            0.027596  0.010132    0.042506  1.540263  0.003554    1.015571
# 289            0.019997  0.010132    0.042506  2.125563  0.005365    1.023507
#
#      antecedents_length  consequents_length
# 284                   2                   1
# 319                   2                   1
# 260                   2                   1
# 307                   2                   1
# 214                   1                   1
# ..                  ...                 ...
# 209                   1                   1
# 340                   1                   2
# 38                    1                   1
# 305                   1                   2
# 289                   1                   2
#
# [348 rows x 11 columns]

# %% [markdown]
# From the above table, the customer who bought (eggs, ground beef) is expected to buy (mineral water) with a likelihood of 50% (confidence). Lift & conviction scores support that hypothesis too and it would be better to keep them close to increase sales
